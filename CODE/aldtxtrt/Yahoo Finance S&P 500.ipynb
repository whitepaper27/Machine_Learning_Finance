# %%
import yfinance as yf
import pandas as pd
import time
import datetime
from datetime import datetime, timedelta

# %% [markdown]
# This is for all US Stocks Only (Excludiing ETF/Bonds)

# %% [markdown]
# This is S&P 500

# %%
stock_symbol = pd.read_csv("S&P500-Symbols.csv") ##File to read coressponding to name

# %%
stock_symbol
# Out:
#      Unnamed: 0 Symbol
# 0             0    MMM
# 1             1    ABT
# 2             2   ABBV
# 3             3   ABMD
# 4             4    ACN
# ..          ...    ...
# 500         500    YUM
# 501         501   ZBRA
# 502         502    ZBH
# 503         503   ZION
# 504         504    ZTS
#
# [505 rows x 2 columns]

# %%
list_of_tickers_sp500 = stock_symbol['Symbol'].tolist()

# %%
list_of_tickers_sp500.append('^IXIC')
list_of_tickers_sp500.append('^gspc')
list_of_tickers_sp500.append('^DJI')
list_of_tickers_sp500.append('^RUT')
list_of_tickers_sp500.append('CL=F')
list_of_tickers_sp500.append('GC=F')
list_of_tickers_sp500.append('^RUT')

# %%
list_of_tickers_sp500
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
# ...

# %%
for i in list_of_tickers_sp500:
    ticker=yf.Ticker(i)
    df=ticker.history(period="1d")
    current_time = datetime.now()
    daily_date = current_time.strftime('%m_%d_%Y')
    pd_daily = pd.DataFrame(df)
    name='Ticker_Values_market.csv'
    pd_daily['Ticker']=i
    pd_daily.to_csv(name,mode='a', header=False)
    #print(df)
# Out:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted
